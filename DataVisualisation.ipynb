# %% [markdown]
# # Data visualisation
# ### Target and features
#
# ---

# %%
import os

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ADA as example.

# %%
ADA = pd.read_csv("data/ADA/ADAUSD_PERP-bookTicker-2024-04-01.csv")

ADA.head()
# Out:
#       update_id  best_bid_price  best_bid_qty  best_ask_price  best_ask_qty  \
# 0  904653769578          0.6509         534.0           0.651         658.0
# 1  904653883958          0.6509         534.0           0.651         648.0
# 2  904653883962          0.6509        1244.0           0.651         648.0
# 3  904653884368          0.6509        1245.0           0.651         648.0
# 4  904653885717          0.6509        1243.0           0.651         648.0
#
#    transaction_time     event_time
# 0     1711929600024  1711929600031
# 1     1711929600325  1711929600355
# 2     1711929600325  1711929600355
# 3     1711929600327  1711929600361
# 4     1711929600334  1711929600364

# %% [markdown]
# Assume that the time difference between each line is aproximately equal.

# %%
ADA = ADA[[
    "best_bid_price",
    "best_bid_qty",
    "best_ask_price",
    "best_ask_qty",
]]

ADA["mid_price"] = (ADA["best_bid_price"] + ADA["best_ask_price"]) / 2

ADA.head()
# Out:
#    best_bid_price  best_bid_qty  best_ask_price  best_ask_qty  mid_price
# 0          0.6509         534.0           0.651         658.0    0.65095
# 1          0.6509         534.0           0.651         648.0    0.65095
# 2          0.6509        1244.0           0.651         648.0    0.65095
# 3          0.6509        1245.0           0.651         648.0    0.65095
# 4          0.6509        1243.0           0.651         648.0    0.65095

# %%
plt.plot(ADA["mid_price"])
plt.title("ADA mid price")
plt.xlabel("")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
# histogram of quantity
plt.hist(ADA["best_bid_qty"], bins=100)
plt.title("ADA best bid quantity")
plt.xlabel("Quantity")
plt.ylabel("Frequency")
plt.show()
